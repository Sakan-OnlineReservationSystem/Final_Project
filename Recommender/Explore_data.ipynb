# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.6.1)

# %%
import pymongo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
def get_data():
    db_client = pymongo.MongoClient('mongodb+srv://ahmedhesham122000:SakanDataBase@sakandatabase.8xx7paz.mongodb.net/?retryWrites=true&w=majority&appName=SakanDatabase')
    print('database connected successfully..')
    sakan_db = db_client['test']
    collection =sakan_db['hotels']
    collection_list =list(collection.find())
    df = pd.DataFrame(collection_list)
    print('Data was collected successfully...')
    return df

# %%
df = get_data()
# Out:
# database connected successfully..
# Data was collected successfully...

# %%
df.head()
# Out:
#                         _id                                   name   type  \
# 0  65df9e90d1edf62697139baf             Hilton Alexandria Corniche  hotel
# 1  65df9e91d1edf62697139bb6  Helnan Royal Hotel - Montazah Gardens  hotel
# 2  65df9e94d1edf62697139bc6          Hilton Alexandria Green Plaza  hotel
# 3  65df9e95d1edf62697139bd5           The Grand Plaza Hotel Smouha  hotel
# 4  65df9e97d1edf62697139be0                 Plaza Hotel Alexandria  hotel
#
#          city country                                            address  \
# 0  alexandria   egypt  \n544 El Geish Road , Sidi Bishr, 21611 Alexan...
# 1        alex   egypt    \nAl Montazah Palace, 99999 Alexandria, Egypt\n
# 2        alex   egypt  \n14th of May Bridge Road - Smouha, Alexandria...
# 3        alex   egypt  \n14th May Avenue, Smouha, 21648 Alexandria, E...
# 4        alex   egypt   \n394 El Gaish Ave, Zizinia, Alexandria, Egypt\n
#
#    distance                                             photos  \
# 0      32.0  [https://cf.bstatic.com/xdata/images/hotel/max...
# 1      18.0  [https://cf.bstatic.com/xdata/images/hotel/max...
# 2      23.0  [https://cf.bstatic.com/xdata/images/hotel/max...
# 3      26.0  [https://cf.bstatic.com/xdata/images/hotel/max...
# 4      21.0  [https://cf.bstatic.com/xdata/images/hotel/max...
#
#                                                 desc  rating  \
# 0  Boasting an ideal location in the heart of Ale...     5.0
# 1  Set on 350 acres of lush gardens overlooking a...     8.1
# 2  On site of Green Plaza Mall, this Hilton is on...     7.9
# 3  The Grand Plaza Hotel is a hotel set in the he...     8.0
# 4  Situated on Alexandria’s Corniche, Alexandria ...     7.3
#
#                                                rooms  cheapestPrice  featured  \
# 0  [65df9e8ad1edf62697139b9f, 65df9e8dd1edf626971...          700.0      True
# 1  [65df9e91d1edf62697139bb0, 65df9e91d1edf626971...          700.0      True
# 2  [65df9e92d1edf62697139bb7, 65df9e92d1edf626971...          700.0      True
# 3  [65df9e94d1edf62697139bc7, 65df9e94d1edf626971...          700.0      True
# 4  [65df9e96d1edf62697139bd6, 65df9e96d1edf626971...          700.0      True
#
#                                              aminity  numberOfReviewers  \
# 0  [Outdoor swimming pool, Beachfront, Free WiFi,...                  1
# 1  [Outdoor swimming pool, Beachfront, Free WiFi,...                  0
# 2  [2 swimming pools, Free WiFi, Private parking,...                  0
# 3  [Free WiFi, Private parking, Family rooms, Res...                  0
# 4  [Free WiFi, Family rooms, 2 restaurants, Room ...                  0
#
#   numberOfStars     score  numRatings reviewScore  __v
# 0             2  7.594575         1.0   Wonderful  NaN
# 1             5  8.100000         NaN  Very Good"  NaN
# 2             3  7.900000         NaN        Good  NaN
# 3             7  8.000000         NaN    Pleasant  NaN
# 4             7  7.300000         NaN   Wonderful  NaN

# %%
countries = df['country'].value_counts()
countries
# Out:
# country
# egypt    3092
# Name: count, dtype: int64

# %%
plt.pie(countries, labels = countries.index, autopct= '%0.2f');

# %%
types = df['type'].value_counts()
types
# Out:
# type
# hotel    3093
# Name: count, dtype: int64

# %%
plt.pie(types, labels=types.index, autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7aec735e77f0>],
#  [Text(-1.1, 1.3471114790620887e-16, 'hotel')],
#  [Text(-0.6, 7.347880794884119e-17, '100.00')])

# %%
df['rating'].hist()
# Out:
# <Axes: >

# %%
df['score'].hist()
# Out:
# <Axes: >

# %%
df['cheapestPrice'].hist()
# Out:
# <Axes: >

# %%
df['numRatings'].hist()
# Out:
# <Axes: >

# %%
df['numberOfReviewers'].hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['_id', 'name', 'type', 'city', 'country', 'address', 'distance',
#        'photos', 'desc', 'rating', 'rooms', 'cheapestPrice', 'featured',
#        'aminity', 'numberOfReviewers', 'numberOfStars', 'score', 'numRatings',
#        'reviewScore', '__v'],
#       dtype='object')

# %%
df[['rating','cheapestPrice', 'numberOfReviewers', 'score']].hist()
# Out:
# array([[<Axes: title={'center': 'rating'}>,
#         <Axes: title={'center': 'cheapestPrice'}>],
#        [<Axes: title={'center': 'numberOfReviewers'}>,
#         <Axes: title={'center': 'score'}>]], dtype=object)

# %%
cities = df['city'].value_counts()
cities
# Out:
# city
# cairo              713
# hurghada           707
# el-alamein         379
# alex               364
# sharm-el-sheikh    279
# dahab              213
# luxor              204
# aswan              120
# marsa-matruh       113
# alexandria           1
# Name: count, dtype: int64

# %%
plt.pie(cities, labels = cities.index, autopct='%0.2f')
plt.show();

# %%
df['city'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='city'>
